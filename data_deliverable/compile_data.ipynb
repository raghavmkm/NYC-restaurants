# %%
import pandas as pd

# %% [markdown]
# In this jupyter note book, we combine three datasets that we found online. We combine restaurant data in NYC, with neighbourhood median income and restaurant violation data. We perform some cleaning of the data as well to remove NaN values. This cleaning step is done after already doing some data preparation on Excel.

# %%
incomes_df = pd.read_csv("Median Incomes 2021 Clean.csv")

# %%
print(incomes_df)
# Out:
#            Neighbourhood  Median Household Income 2021
# 0          New York City                    67997.0000
# 1              Manhattan                    84435.0000
# 2   Battery Park/Tribeca                    57565.1155
# 3      Greenwich Village                    84977.8845
# 4        Lower East Side                    49685.0000
# ..                   ...                           ...
# 60         The Rockaways                    51643.0000
# 61         Staten Island                    86054.0000
# 62            St. George                    72727.0000
# 63           South Beach                    81111.0000
# 64           Tottenville                   103200.0000
#
# [65 rows x 2 columns]

# %%
restaurants_df = pd.read_csv("Cleaned Restaurant data.csv")

# %%
restaurants_df
# Out:
#                                       Name  Rating  Rating Count  \
# 0    The Firehouse Family Restaurant & Bar     4.6         549.0
# 1             H Restaurant & SS Restaurant     NaN           NaN
# 2                         Joe's Restaurant     4.6         812.0
# 3            Mompou Tapas Bar & Restaurant     4.4        1136.0
# 4                                    Rasoi     3.9        1904.0
# ..                                     ...     ...           ...
# 665           4 Caminos Mexican Restaurant     4.1         184.0
# 666            Pakshala Restaurant & Grill     5.0         151.0
# 667               Family Meal at Blue Hill     4.6        1143.0
# 668        La Posada Taqueria & Restaurant     4.0         444.0
# 669               CAFE TROPICAL RESTAURANT     4.1          78.0
#
#                                       Detailed Ratings  Price Category  \
# 0    {'Rating 5 ': 399.0, 'Rating 4 ': 105.0, 'Rati...             1.0
# ...

# %%
filtered_restaurants_df = restaurants_df[restaurants_df['Rating'].notnull()]
filtered_restaurants_df
# Out:
#                                       Name  Rating  Rating Count  \
# 0    The Firehouse Family Restaurant & Bar     4.6         549.0
# 2                         Joe's Restaurant     4.6         812.0
# 3            Mompou Tapas Bar & Restaurant     4.4        1136.0
# 4                                    Rasoi     3.9        1904.0
# 5                         Restaurant Oyola     4.2         438.0
# ..                                     ...     ...           ...
# 665           4 Caminos Mexican Restaurant     4.1         184.0
# 666            Pakshala Restaurant & Grill     5.0         151.0
# 667               Family Meal at Blue Hill     4.6        1143.0
# 668        La Posada Taqueria & Restaurant     4.0         444.0
# 669               CAFE TROPICAL RESTAURANT     4.1          78.0
#
#                                       Detailed Ratings  Price Category  \
# 0    {'Rating 5 ': 399.0, 'Rating 4 ': 105.0, 'Rati...             1.0
# ...

# %%
new_york_only = filtered_restaurants_df[~filtered_restaurants_df["Address"].str.contains("NJ")]

# %%
new_york_only
# Out:
#                                     Name  Rating  Rating Count  \
# 2                       Joe's Restaurant     4.6         812.0
# 6       Mexican Cantina Restaurant & Bar     4.5         257.0
# 8      Golden Krust Caribbean Restaurant     3.7          82.0
# 12                   POLONICA RESTAURANT     4.5         227.0
# 13   Serafina Italian Restaurant Tribeca     4.3        1057.0
# ..                                   ...     ...           ...
# 663                 Cedric's at The Shed     4.6         100.0
# 664             CC'S Jamaican Restaurant     4.6          99.0
# 665         4 Caminos Mexican Restaurant     4.1         184.0
# 666          Pakshala Restaurant & Grill     5.0         151.0
# 667             Family Meal at Blue Hill     4.6        1143.0
#
#                                       Detailed Ratings  Price Category  \
# 2    {'Rating 5 ': 651.0, 'Rating 4 ': 99.0, 'Ratin...             2.0
# ...

# %%
violation_df = pd.read_csv("violation data.csv")

# %%
violation_df
# Out:
#          CAMIS                                   DBA       BORO BUILDING  \
# 0     50147475                            LIGHT SALT  Manhattan      275
# 1     50147201  APPLEBEES NEIGHBORHOOD GRILL AND BAR     Queens    90-15
# 2     50111182                THE ALCHEMISTS KITCHEN  Manhattan      117
# 3     50149855                                   NaN     Queens     4036
# 4     50150145                   LIMELIGHT GRIMALDIS          0      NaN
# ...        ...                                   ...        ...      ...
# 2494  50113356                        POETICA COFFEE   Brooklyn      561
# 2495  50095788                           SHAXIAN 888   Brooklyn     6024
# 2496  50018036                 BUSHWICK PUBLIC HOUSE   Brooklyn      201
# 2497  50091187                             Luv Pizza  Manhattan      485
# 2498  50117060                     TALK OF THE TRACK     Queens   110-00
#
#                   STREET  ZIPCODE       PHONE CUISINE DESCRIPTION  \
# ...

# %% [markdown]
# The original goal was to combine these two dataframes. However after looking at the two of them and trying for a few days, we figured there was no common index between the two dataframes. The manner in which they are indexed is different in both and to top it off the names of the restaurants we want to look at are different. We tried to manually match the two on excel but punching in the values took way too long. It took like an hour just for 15 entries as we had to aggregate all the violations per restaurant and match it with the other. Moreover, the properties we want to test don't require the restaurants to be merged. We want to find relationships between neighbourhood and violations, money and ratings and ethnicity and violations. The first and last are entirely in table 3 and the second is in table 2.
